# %% [markdown]
# In this notebook we will notebook , we will recover and analyse data from AlphaAdvantage . Lets get all the form of data that we can extract from AlphaAdvantage and Store it in Snowflake.

# %%
import pandas as pd
import requests

# %% [markdown]
# Lets get the Physical Currency and  Cryptocurrency
